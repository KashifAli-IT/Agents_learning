# %% [markdown]
# <a href="https://colab.research.google.com/github/KashifAli-IT/Agents_learnig/blob/agentOne_shake/milkshake_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <details>
# <summary>Click to expand/collapse text</summary>
#
# # 🧠 AI Agent Demo — Learning with Analogy
#
# ## 🎯 Goal of This Notebook
#
# In this notebook, we will understand:
#
# - What an AI Agent is
# - How it thinks and acts
# - How it is similar to a human solving a problem
#
# ---
#
# ## 💡 Big Idea
#
# > An AI Agent is like a human worker.
#
# It does not just answer…
# It **thinks, takes actions, observes results, and improves**.
#
# ---
#
# ## 🥤 Running Example: Making a Milkshake
#
# We will see everything using a simple analogy:
#
# 👉 A human making a milkshake
#
# And then show:
# 👉 How an AI agent does the SAME process
#
# </details>

# %%
# !pip install smolagents groq openai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.5/161.5 kB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 15.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# <details>
# <summary>Click to expand/collapse text</summary>
#
# #  🧍 Human Example: Making a Milkshake
#
# Let’s say we give a human a goal:
#
# 👉 “Make a milkshake”
#
# ### Step 1: Think 🤔
# - Do I have bananas?
# - Do I have milk?
# - Do I have sugar?
#
# ### Step 2: Act 🛠️
# - Go to kitchen
# - If something missing → go buy it
#
# ### Step 3: Observe 👀
# - Are ingredients good?
# - Is something missing?
#
# ### Step 4: Repeat 🔁
# - Fix issues
# - Try again
#
# ### Step 5: Improve ✅
# - Taste it
# - Adjust sugar or milk
#
# ---
#
# ## 🔁 This is a LOOP
#
# **Think → Act → Observe → Repeat**
#
# 👉 This is exactly how AI Agents work
#
# </details>

# %%
import os
from smolagents import CodeAgent, tool, ToolCallingAgent
from openai import OpenAI
from google.colab import userdata

client = OpenAI(
    api_key=userdata.get("testing"),
    base_url="https://api.groq.com/openai/v1"
)

# %% [markdown]
# <details>
# <summary>Click to expand/collapse text</summary>
#
# # 🤖 AI Agent = Digital Human
#
# Now let’s map human behavior to AI:
#
# | Human | AI Agent |
# |------|--------|
# | Brain | LLM (AI Model) |
# | Thinking | Planning |
# | Hands | Tools |
# | Memory | Context |
# | Actions | Tool Calls |
# | Learning | Feedback Loop |
#
# ---
#
# ## 💡 Key Idea
#
# > ChatGPT = Thinks only
# > AI Agent = Thinks + Acts
#
# ---
#
# So instead of just answering…
#
# 👉 The agent will:
# - Decide what to do
# - Use tools
# - Fix mistakes
# - Try again
#
# </details>

# %%
from smolagents.models import ChatMessage

class GroqModel:
    def __init__(self, client, model="llama-3.3-70b-versatile"):
        self.client = client
        self.model = model

    def generate(self, messages, stop_sequences=None):
        formatted_messages = [
            {
                "role": m.role if m.role in ["system", "user", "assistant"] else "assistant",
                "content": m.content
            }
            for m in messages
        ]

        response = self.client.chat.completions.create(
            model=self.model,
            messages=formatted_messages,
            temperature=0
        )

        # ✅ RETURN ChatMessage (what CodeAgent expects)
        return ChatMessage(
            role="assistant",
            content=response.choices[0].message.content
        )

# %% [markdown]
# <details>
# <summary>Click to expand/collapse text</summary>
#
# # 🛠️ Tools = Agent’s Hands
#
# Humans use:
# - Hands
# - Eyes
# - Actions
#
# AI Agents use:
# - Functions (tools)
#
# ---
#
# ## 🧪 In This Demo
#
# We give the agent these tools:
#
# - Check ingredients → (Look in kitchen)
# - Buy ingredient → (Go to market)
# - Make milkshake → (Final action)
#
# ---
#
# ## 💡 Key Idea
#
# > Tools turn AI from “thinking” → into “doing”
# </details>

# %%
# Kitchen state (start with missing banana)
kitchen = {
    "banana": False,
    "milk": False,
    "sugar": True
}

@tool
def check_ingredients() -> dict:
    """
    Check available ingredients in the kitchen.

    Returns:
        dict: A dictionary of ingredients and their availability.
    """
    print("👀 Agent is checking ingredients from fridge/kitchen...")
    return kitchen


@tool
def buy_ingredient(item: str) -> str:
    """
    Buy a missing ingredient.

    Args:
        item (str): Name of the ingredient to purchase.

    Returns:
        str: Confirmation message after buying the ingredient.
    """
    print(f"🧠 Agent decided to buy {item}")
    print(f"🛒 Buying {item}...")
    kitchen[item] = True
    return f"{item} purchased"


@tool
def make_milkshake() -> str:
    """
    Make milkshake if all ingredients are available.

    Returns:
        str: Result of milkshake preparation.
    """
    print("🥤 Attempting to make milkshake...")
    print("🥤 Agent is making milkshake...")

    if all(kitchen.values()):
        return "Milkshake is ready! 🎉"
    else:
        return "Missing ingredients, cannot make milkshake"

# %% [markdown]
# <details>
# <summary>Click to expand/collapse text</summary>
#
# # 🧠 The Brain (LLM)
#
# The brain of the agent is an AI model (like LLaMA).
#
# Its job:
# - Understand the goal
# - Decide next step
# - Choose which tool to use
#
# ---
#
# ## 💡 Important
#
# The model is NOT pre-programmed with steps.
#
# 👉 It decides dynamically:
# - What to do first
# - What to do next
# - When to stop
# </details>

# %%
llm = GroqModel(client)

agent = CodeAgent(
    tools=[check_ingredients, buy_ingredient, make_milkshake],
    model=llm,
    verbosity_level=2,
    max_steps=5,
    instructions="""
You are Ayaan, a helpful and smart assistant.

You help in the kitchen by:
1. Checking ingredients
2. Buying missing items
3. Completing the task

You think step by step and use tools when needed.
"""
)

# %% [markdown]
# <details>
# <summary>Click to expand/collapse text</summary>
#
# # 🚀 Running the Agent
#
# Now we give the agent a goal:
#
# 👉 “Make a milkshake”
#
# ---
#
# ## 🧠 What Will Happen?
#
# The agent will:
#
# 1. Think → What do I need?
# 2. Act → Call tools
# 3. Observe → Check results
# 4. Repeat → Until goal is complete
#
# ---
#
# ## 🔁 This is called:
#
# > The Agent Loop
# > Think → Act → Observe → Repeat
#
# ---
#
# ## 👀 While Running
#
# Watch for:
# - Thinking steps
# - Tool usage
# - Decisions
#
# This is the agent behaving like a human
# </details>

# %%
agent.run("Make a milkshake")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Make a milkshake                                                                                                │
# │                                                                                                                 │
# ╰─ GroqModel -  ──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Output message of the LLM: ────────────────────────────────────────────────────────────────────────────────────────
# Thought: To make a milkshake, I first need to check if all the necessary ingredients are available in the kitchen.
# ...

# %% [markdown]
# <details>
# <summary>Click to expand/collapse text</summary>
#
# # 🧠 What Just Happened?
#
# Let’s connect it back:
#
# - Agent received a goal ✅
# - It planned steps ✅
# - It used tools ✅
# - It fixed problems ✅
# - It completed the task ✅
#
# ---
#
# ## 💡 Final Understanding
#
# > AI Agents are not just answering machines
#
# They are:
# - Problem solvers
# - Decision makers
# - Action takers
#
# ---
#
# ## 🚀 Real-World Use Cases
#
# This same idea can be used for:
#
# - Research assistant
# - Study helper
# - Customer support bot
# - Task automation
# - Personal assistant
#
# ---
#
# ## 🔥 Final Thought
#
# > You don’t need to train AI
# > You just need to give it:
# - A goal
# - Tools
# - A way to think
# </details>
